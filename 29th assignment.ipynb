# %% [markdown]
# ##Run the following programme and enter question number between 1 to 16:

# %%
q=int(input("Enter question number between 1to 16: "))
if q==1:
    print('''1.Who developed python programming language?\n 
Ans.- Python was created by Guido van Rossum, and first released on February 20, 1991.''')
elif q==2:
    print('''2. Which type of Programming does Python support?\n
Ans.- Python is a multi-paradigm programming language.Object-oriented programming and structured programming are fully supported, and many of their features support functional programming and aspect-oriented programming (including metaprogramming and metaobjects).''')
elif q==3:
    print('''3. Is Python case sensitive when dealing with identifiers? \n
Ans.- Yes, Python is a case-sensitive language, i.e., it treats uppercase and lowercase characters differently.
This applies to identifiers too. You must avoid using the same name with different cases while naming identifiers.''')    
elif q==4:
    print('''4. What is the correct extension of the Python file? \n
Ans.- Python is a widely used programming or coding language used for different purposes. The extensions for Python files are - . py. ''')
elif q==5:
    print( '''5. Is Python code compiled or interpreted? \n
Ans.- Python is both compiled as well as an interpreted language, which means when we run a python code, it is first compiled and then interpreted line by line.''')
elif q==6:
    print('''6. Name a few blocks of code used to define in Python language? \n
Ans.- def block: used to define a function.
    if block: used to specify a block of code to be executed only if a condition is met.
    for block: used to iterate over a sequence (such as a list, tuple, or string) and execute a block of code for each item.
    while block: used to repeat a block of code as long as a given condition is true.
    try block: used to handle exceptions (run-time errors) that may occur in the code.
    with block: used to wrap the execution of a block of code with methods defined by a context manager.''')
elif q==7:
    print('''7. State a character used to give single-line comments in Python? \n
Ans.- We can write a single-line comment by adding a single # character before any statement or line of code.
''')
elif q==8:
    print('''8. Mention functions which can help us to find the version of python that we are currently working on? \n
Ans.- One can find the version of Python currently using by using the following methods: 
    1.In the Python interpreter:
        >>> import sys
        >>> print(sys.version)
    2.In the command prompt or terminal:
        $ python --version
    3.In a Python script:
        import sys
        print(sys.version) ''')
elif q==9:
    print('''9. Python supports the creation of anonymous functions at runtime, using a construct called... \n
Ans.- Python supports to make anonymous functions which are not bound to a name(@ runtime). It uses a construct called "lambda" 
''')
elif q==10:
    print('''10. What does pip stand for python? \n
Ans.- PIP is a recursive acronym for “Preferred Installer Program” or PIP Installs Packages.
It is a command-line utility that installs, reinstalls, or uninstalls PyPI packages with one simple command: pip.''')
elif q==11:
    print('''11. Mention a few built-in functions in python? \n
Ans.- The built-in Python functions are pre-defined by the python interpreter. There are 68 built-in python functions. These functions perform a specific task and can be used in any program, depending on the requirement of the user.Some of the are 
    print( ) function
    type( ) function
    input( ) function
    abs( ) function
    pow( ) function
    dir( ) function
    sorted( ) function
    max( ) function
    round( ) function
    divmod( ) function
    id( ) function
    ord( ) function
    len( ) function
    sum( ) function
    help( ) function
    etc...''')
elif q==12:
    print('''12. What is the maximum possible length of an identifier in Python? \n
Ans.- "Python identifiers are unlimited in length" but as per PEP-8 you should limit identifier to a maximum of 79 character for better readability but there is no restriction.''')
elif q==13:
    print('''13. What are the benefits of using Python? \n
Ans.- Python is commonly used for developing websites and software, task automation, data analysis, and data visualization. Since it's relatively easy to learn, Python has been adopted by many non-programmers such as accountants and scientists, for a variety of everyday tasks, like organizing finances.Python is a general-purpose object-oriented programming language created by Guido van Rossum — which means that, unlike HTML, CSS, and JavaScript, it can be used for other types of programming, such as: back end development, software development, data science, and writing system scripts (automation), among other uses.''')
elif q==14:
    print('''14. How is memory managed in Python? \n
Ans.- Memory in Python is managed by Python private heap space. All Python objects and data structures are located in a private heap. This private heap is taken care of by Python Interpreter itself, and a programmer doesn't have access to this private heap.Python uses a portion of the memory for internal use and non-object memory. Another part of the memory is used for Python object such as int, dict, list, etc. CPython contains the object allocator that allocates memory within the object area.''')
elif q==15:
    print('''15. How to install Python on Windows and set path variables? \n
Ans.- 1.Download the Python installation file from the official website: https://www.python.org/downloads/
    2.Run the installation file and follow the on-screen instructions.
    3.Make sure to select the option to add Python to the PATH environment variable during the installation process.
    If one did not add Python to the PATH during installation, one can set the PATH environment variable manually as follows:

    4.Open the Start menu and search for "Environment Variables"
    5.Click on "Edit the system environment variables"
    6.In the System Properties window, click on the "Environment Variables" button.
    7.Under "System Variables", scroll down and find the "Path" variable, then click on "Edit"
    8.Add the path to your Python installation, typically "C:\PythonXX\Scripts" (XX represents the version number)
    9.Restart any open command prompts or open a new one for the changes to take effect.
    You can then verify the installation by opening a command prompt and typing python to start the Python interpreter.''')
elif q==16:
    print('''16. Is indentation required in python? \n
Ans.-Indentation is mandatory in python to define the blocks of statements. It is preferred to use whitespaces instead of tabs to indent in python. Python uses four spaces as default indentation spaces.In Python, all the code that you type is arranged via correct whitespaces and therefore if at any instance you have a bad indentation, the overall code will not run and the interpreter will simply return an error function.t is necessary to do so for the interpreter to understand that it is in a loop or a condition.
 ''')
else:
    print("Please,enter valid question number between 1 to 16.")
